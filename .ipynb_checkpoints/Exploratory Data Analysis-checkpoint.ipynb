# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from utils import get_dataset
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import tensorflow as tf

# %matplotlib inline

# %%
dataset = get_dataset("/home/workspace/data/*/*.tfrecord")
dataset
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/*/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/*/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 99
# ...

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_images` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_images(batch):
    # TODO - Your implementation here
    colorCode = {1:"red",2:'blue',3:"green"}
    figure,axes = plt.subplots()
    image = batch["image"].numpy()
    axes.imshow(image)
    #Apply BBox to image
    for coord,label in zip(batch["groundtruth_boxes"].numpy(),batch["groundtruth_classes"].numpy()):
        ax = (coord[1]*image.shape[1],coord[0]*image.shape[0])
        width = (coord[3]-coord[1])*image.shape[1]
        height = (coord[2]-coord[0])*image.shape[0]
        rect = patches.Rectangle(ax,width,height,linewidth=1,edgecolor=colorCode[label])
        axes.add_patch(rect)

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
# Display 10 random images in dataset
plt.figure(figsize=(10,10))
for image in range(10):
    for batch in dataset.shuffle(80,reshuffle_each_iteration=True).take(1):
        display_images(batch)
plt.show()
# Out:
# -------------------------------------------------------------------
# AttributeError                    Traceback (most recent call last)
# <ipython-input-9-555f006f1114> in <module>
#       3 for image in range(10):
#       4     for batch in dataset.shuffle(80,reshuffle_each_iteration=True).take(1):
# ----> 5         display_images(batch)
#       6 plt.show()
#
# <ipython-input-8-321c977ffd23> in display_images(batch)
#      11         height = (coord[2]-coord[0])*image.shape[0]
#      12         rect = patches.Rectangle(ax,width,height,linewidth=1,edgecolor=colorCode[label])
# ---> 13         axes.add_pathc(rect)
#
# AttributeError: 'AxesSubplot' object has no attribute 'add_pathc'

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...
