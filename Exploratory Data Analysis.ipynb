# %% [markdown]
# # Explore the dataset
#
#
# In this notebook, we will perform an EDA (Exploratory Data Analysis) on the processed Waymo dataset (data in the `processed` folder). In the first part, you will create a function to display

# %%
from utils import get_dataset
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import tensorflow as tf

# %matplotlib inline

# %%
dataset = get_dataset("/home/workspace/data/train/*.tfrecord")
dataset
# Out:
# INFO:tensorflow:Reading unweighted datasets: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/workspace/data/train/*.tfrecord']
# INFO:tensorflow:Number of filenames to read: 86
# WARNING:tensorflow:From /data/virtual_envs/sdc-c1-gpu-augment/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# ...

# %% [markdown]
# ## Write a function to display an image and the bounding boxes
#
# Implement the `display_images` function below. This function takes a batch as an input and display an image with its corresponding bounding boxes. The only requirement is that the classes should be color coded (eg, vehicles in red, pedestrians in blue, cyclist in green).

# %%
def display_images(batch):
    # TODO - Your implementation here
    colorCode = {1:"red",2:'blue',3:"green"}
    figure,axes = plt.subplots()
    image = batch["image"].numpy()
    axes.imshow(image)
    #Apply BBox to image
    for coord,label in zip(batch["groundtruth_boxes"].numpy(),batch["groundtruth_classes"].numpy()):
        ax = (coord[1]*image.shape[1],coord[0]*image.shape[0])
        width = (coord[3]-coord[1])*image.shape[1]
        height = (coord[2]-coord[0])*image.shape[0]
        rect = patches.Rectangle(ax,width,height,linewidth=1,edgecolor=colorCode[label],facecolor='None')
        axes.add_patch(rect)
    plt.axis("off")

# %% [markdown]
# ## Display 10 images
#
# Using the dataset created in the second cell and the function you just coded, display 10 random images with the associated bounding boxes. You can use the methods `take` and `shuffle` on the dataset.

# %%
# Display 10 random images in dataset
plt.figure(figsize=(10,10))
for image in range(10):
    for batch in dataset.shuffle(80,reshuffle_each_iteration=True).take(1):
        display_images(batch)
plt.show()
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# <ipython-input-6-555f006f1114> in <module>
#       3 for image in range(10):
#       4     for batch in dataset.shuffle(80,reshuffle_each_iteration=True).take(1):
# ----> 5         display_images(batch)
#       6 plt.show()
#
# <ipython-input-5-468cc146832c> in display_images(batch)
#      10         width = (coord[3]-coord[1])*image.shape[1]
#      11         height = (coord[2]-coord[0])*image.shape[0]
# ---> 12         rect = patches.Rectangle(ax,width,height,linewidth=1,edgecolor=colorCode[label],facecolor='None')
#      13         axes.add_patch(rect)
#      14     plt.axis("off")
#
# KeyError: 4

# %% [markdown]
# ## Additional EDA
#
# In this last part, you are free to perform any additional analysis of the dataset. What else would like to know about the data?
# For example, think about data distribution. So far, you have only looked at a single file...

# %%
import matplotlib.pyplot as plt

#Counting cars,pedestrians and cyclist  
lbl = {1:0,2:0,4:0}
dist_lbl = {1:[],2:[],4:[3]}
#Looping through subset of data
for data in dataset.take(5000):
    counter = {1:0,2:0,4:0}
    for gt in data["groundtruth_classes"].numpy():
        lbl[gt]+=1
        counter[gt] +=1
        dist_lbl[gt].append(counter[gt])

labelMap = {"car":lbl[1],"pedestrians":lbl[2],"cyclist":lbl[4]}
labelMap_dist = {"car":dist_lbl[1],"pedestrians":dist_lbl[2],"cyclist":dist_lbl[4]}  

valuesList = [labelMap[key] for key in labelMap.keys()]
plot = plt.figure().add_axes([0,0,1,1])
plot.set_title('Number of each label')



plot_hist_car = plt.figure().add_axes([0,0,1,1])
plot_hist_car.set_title('Distribution of Cars per Image')

plot.bar(labelMap.keys(),valuesList)
plot_hist_car.hist((labelMap_dist["car"]))
plt.show()
